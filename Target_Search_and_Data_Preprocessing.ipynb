# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /usr/local/lib/python3.10/dist-packages (0.10.9)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.2.3)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (2.32.3)
# Requirement already satisfied: requests-cache~=1.2 in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.2.1)
# Requirement already satisfied: easydict in /usr/local/lib/python3.10/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2024.8.30)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.2.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (24.1.2)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.3.6)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: exceptiongroup>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (1.2.2)
# Requirement already satisfied: typing-extensions!=4.6.3,>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.12.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## Search for Target Protein

# %% [markdown]
# **Target** refers to target proteins or organism that the drug will act on. Drug will come into contact with the organism or protein and induce a modulatory activity (activate or inhibit).

# %% [markdown]
# **Hepatitis C** is a **liver disease** caused by the hepatitis C virus (HCV) that can lead to acute or chronic liver disease. Hepatitis C is important to research because it is a significant global health concern, causing chronic liver disease, cirrhosis, and liver cancer if left untreated, and despite recent breakthroughs in treatment, ongoing research is crucial to develop preventive measures like a vaccine, address treatment challenges in difficult populations, and better understand the virus's mechanisms to potentially eradicate it completely

# %%
# Target search for Hepatitis C
target = new_client.target
target_query = target.search('Hepatitis C')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                       cross_references  \
# 0                                                   []
# 1    [{'xref_id': 'P26664', 'xref_name': None, 'xre...
# 2    [{'xref_id': 'D2K2A8', 'xref_name': None, 'xre...
# 3    [{'xref_id': 'Q15004', 'xref_name': None, 'xre...
# 4                                                   []
# ..                                                 ...
# 872                                                 []
# 873                                                 []
# 874                                                 []
# 875                                                 []
# 876                                                 []
#
#                                             organism  \
# 0                                Hepacivirus hominis
# 1    Hepatitis C virus genotype 1a (isolate 1) (HCV)
# 2                                  Hepatitis C virus
# 3                                       Homo sapiens
# 4                                       Homo sapiens
# ..                                               ...
# 872                          Drosophila melanogaster
# 873                                 Escherichia coli
# 874                                     Homo sapiens
# 875                                     Homo sapiens
# 876                                Rattus norvegicus
#
#                                            pref_name  score  \
# 0                                  Hepatitis C virus   19.0
# 1                      Hepatitis C virus polyprotein   17.0
# 2                     Hepatitis C virus NS4A protein   15.0
# 3                             PCNA-associated factor   14.0
# 4              Hepatitis A virus cellular receptor 2   14.0
# ..                                               ...    ...
# 872                 Nicotinic acetylcholine receptor    0.0
# 873  1-deoxy-D-xylulose 5-phosphate reductoisomerase    0.0
# 874              UDP-glucuronosyltransferases (UGTs)    0.0
# 875                                  Cytochrome P450    0.0
# 876                    Glutamate (NMDA/AMPA/Kainate)    0.0
#
#      species_group_flag target_chembl_id  \
# 0                 False        CHEMBL379
# 1                 False       CHEMBL4620
# 2                 False       CHEMBL2364
# 3                 False       CHEMBL5574
# 4                 False    CHEMBL4630879
# ..                  ...              ...
# 872               False    CHEMBL3350223
# 873               False    CHEMBL3421521
# 874               False    CHEMBL4523985
# 875               False    CHEMBL4523986
# 876               False    CHEMBL4524129
#
#                                      target_components            target_type  \
# 0                                                   []               ORGANISM
# 1    [{'accession': 'P26664', 'component_descriptio...         SINGLE PROTEIN
# 2    [{'accession': 'D2K2A8', 'component_descriptio...         SINGLE PROTEIN
# 3    [{'accession': 'Q15004', 'component_descriptio...         SINGLE PROTEIN
# 4    [{'accession': 'Q8TDQ0', 'component_descriptio...         SINGLE PROTEIN
# ..                                                 ...                    ...
# 872  [{'accession': 'P25162', 'component_descriptio...  PROTEIN COMPLEX GROUP
# 873  [{'accession': 'W8T2T2', 'component_descriptio...         SINGLE PROTEIN
# 874  [{'accession': 'P22310', 'component_descriptio...         PROTEIN FAMILY
# 875  [{'accession': 'P08684', 'component_descriptio...         PROTEIN FAMILY
# 876  [{'accession': 'P35439', 'component_descriptio...  PROTEIN COMPLEX GROUP
#
#         tax_id
# 0    3052230.0
# 1      11104.0
# 2    3052230.0
# 3       9606.0
# 4       9606.0
# ..         ...
# 872     7227.0
# 873      562.0
# 874     9606.0
# 875     9606.0
# 876    10116.0
#
# [877 rows x 9 columns]

# %%
# selecting and retrieving bioactivity data for Hepatitis C virus polyprotein
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL4620'

# %% [markdown]
# ## Creating the CSV

# %%
# only retrieve bioactivity dta for Hepatitis C virus polyprotein (CHEMBL4620) that are reported as IC50
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(5)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None        33392                  []
# 1        None             None        33393                  []
# 2        None             None        35906                  []
# 3        None             None        40613                  []
# 4        None             None        40614                  []
#
#   assay_chembl_id                                  assay_description  \
# 0    CHEMBL857692  Inhibitory concentration against HCV NS3 prote...
# 1    CHEMBL857692  Inhibitory concentration against HCV NS3 prote...
# 2    CHEMBL857692  Inhibitory concentration against HCV NS3 prote...
# 3    CHEMBL857692  Inhibitory concentration against HCV NS3 prote...
# 4    CHEMBL857692  Inhibitory concentration against HCV NS3 prote...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#                                    target_organism  \
# 0  Hepatitis C virus genotype 1a (isolate 1) (HCV)
# 1  Hepatitis C virus genotype 1a (isolate 1) (HCV)
# 2  Hepatitis C virus genotype 1a (isolate 1) (HCV)
# 3  Hepatitis C virus genotype 1a (isolate 1) (HCV)
# 4  Hepatitis C virus genotype 1a (isolate 1) (HCV)
#
#                 target_pref_name target_tax_id text_value  toid  type units  \
# 0  Hepatitis C virus polyprotein         11104       None  None  IC50    uM
# 1  Hepatitis C virus polyprotein         11104       None  None  IC50    uM
# 2  Hepatitis C virus polyprotein         11104       None  None  IC50    uM
# 3  Hepatitis C virus polyprotein         11104       None  None  IC50    uM
# 4  Hepatitis C virus polyprotein         11104       None  None  IC50    uM
#
#      uo_units upper_value value
# 0  UO_0000065        None  42.0
# 1  UO_0000065        None   4.3
# 2  UO_0000065        None  12.0
# 3  UO_0000065        None   3.6
# 4  UO_0000065        None  60.0
#
# [5 rows x 46 columns]

# %% [markdown]
# `standard value` represents the potency, the lower the number the better the potency of the drug becomes. Ideally we want the inhibitory concentration at 50% to have a low concentration.

# %%
df['standard_value']
# Out:
# 0      42000.0
# 1       4300.0
# 2      12000.0
# 3       3600.0
# 4      60000.0
#         ...
# 238      950.0
# 239      610.0
# 240      202.0
# 241    27000.0
# 242    18000.0
# Name: standard_value, Length: 243, dtype: object

# %%
df.to_csv('hepatitis_c_bioactivity_data.csv', index=False)

# %%
# mount google drive into notebook
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# create data folder in Colab Notebook fold on google drive
! mkdir "/content/gdrive/My Drive/Colab Notebooks/Computational Drug Discovery: Hepatitis C/hepatitis_c_bioactivity_data"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/Computational Drug Discovery: Hepatitis C/hepatitis_c_bioactivity_data’: File exists

# %%
! cp hepatitis_c_bioactivity_data.csv "/content/gdrive/My Drive/Colab Notebooks/Computational Drug Discovery: Hepatitis C/hepatitis_c_bioactivity_data"

# %%
! ls "/content/gdrive/My Drive/Colab Notebooks/Computational Drug Discovery: Hepatitis C/hepatitis_c_bioactivity_data"
# Out:
# hepatitis_c_bioactivity_data.csv

# %%
! head hepatitis_c_bioactivity_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,33392,[],CHEMBL857692,Inhibitory concentration against HCV NS3 protease was determined,B,,,BAO_0000190,BAO_0000357,single protein format,CC[C@H](NC(=O)[C@H](CC1CCCCC1)NC(=O)[C@@H](NC(=O)[C@H](CC(C)C)NC(=O)c1cnccn1)[C@@H](C)CC)C(=O)C(=O)N1CCCC1,,,CHEMBL1136650,Bioorg Med Chem Lett,2003,"{'bei': '6.53', 'le': '0.12', 'lle': '1.69', 'sei': '2.44'}",CHEMBL273701,,CHEMBL273701,4.38,0,http://www.openphacts.org/units/Nanomolar,12761,=,1,1,=,,IC50,nM,,42000.0,CHEMBL4620,Hepatitis C virus genotype 1a (isolate 1) (HCV),Hepatitis C virus polyprotein,11104,,,IC50,uM,UO_0000065,,42.0
# ,,33393,[],CHEMBL857692,Inhibitory concentration against HCV NS3 protease was determined,B,,,BAO_0000190,BAO_0000357,single protein format,CC[C@H](NC(=O)[C@H](CC1CCCCC1)NC(=O)[C@@H](NC(=O)[C@H](CC(C)C)NC(=O)c1cnccn1)[C@@H](C)CC)C(=O)C(=O)NCC(N)=O,,,CHEMBL1136650,Bioorg Med Chem Lett,2003,"{'bei': '7.98', 'le': '0.15', 'lle': '4.70', 'sei': '2.32'}",CHEMBL276488,,CHEMBL276488,5.37,0,http://www.openphacts.org/units/Nanomolar,12755,=,1,1,=,,IC50,nM,,4300.0,CHEMBL4620,Hepatitis C virus genotype 1a (isolate 1) (HCV),Hepatitis C virus polyprotein,11104,,,IC50,uM,UO_0000065,,4.3
# ,,35906,[],CHEMBL857692,Inhibitory concentration against HCV NS3 protease was determined,B,,,BAO_0000190,BAO_0000357,single protein format,CC[C@H](NC(=O)[C@H](CC1CCCCC1)NC(=O)[C@@H](NC(=O)[C@H](CC(C)C)NC(=O)c1cnccn1)[C@@H](C)CC)C(=O)C(=O)NCCC(=O)O,,,CHEMBL1136650,Bioorg Med Chem Lett,2003,"{'bei': '7.15', 'le': '0.14', 'lle': '3.26', 'sei': '2.18'}",CHEMBL13773,,CHEMBL13773,4.92,0,http://www.openphacts.org/units/Nanomolar,12753,=,1,1,=,,IC50,nM,,12000.0,CHEMBL4620,Hepatitis C virus genotype 1a (isolate 1) (HCV),Hepatitis C virus polyprotein,11104,,,IC50,uM,UO_0000065,,12.0
# ,,40613,[],CHEMBL857692,Inhibitory concentration against HCV NS3 protease was determined,B,,,BAO_0000190,BAO_0000357,single protein format,CC[C@H](NC(=O)[C@H](CC1CCCCC1)NC(=O)[C@@H](NC(=O)[C@H](CC(C)C)NC(=O)c1cnccn1)[C@@H](C)CC)C(=O)C(=O)N[C@H](C(=O)O)C(C)C,,,CHEMBL1136650,Bioorg Med Chem Lett,2003,"{'bei': '7.60', 'le': '0.15', 'lle': '3.14', 'sei': '2.41'}",CHEMBL13442,,CHEMBL13442,5.44,0,http://www.openphacts.org/units/Nanomolar,12748,=,1,1,=,,IC50,nM,,3600.0,CHEMBL4620,Hepatitis C virus genotype 1a (isolate 1) (HCV),Hepatitis C virus polyprotein,11104,,,IC50,uM,UO_0000065,,3.6
# ,,40614,[],CHEMBL857692,Inhibitory concentration against HCV NS3 protease was determined,B,,,BAO_0000190,BAO_0000357,single protein format,CC[C@H](C)[C@H](NC(=O)[C@H](CC(C)C)NC(=O)c1cnccn1)C(=O)N[C@@H](CC1CCCCC1)C(=O)NC(C)(C)C(=O)C(=O)NCC(=O)O,,,CHEMBL1136650,Bioorg Med Chem Lett,2003,,CHEMBL266854,,CHEMBL266854,,0,http://www.openphacts.org/units/Nanomolar,12745,>,1,1,>,,IC50,nM,,60000.0,CHEMBL4620,Hepatitis C virus genotype 1a (isolate 1) (HCV),Hepatitis C virus polyprotein,11104,,,IC50,uM,UO_0000065,,60.0
# ,,43080,[],CHEMBL857692,Inhibitory concentration against HCV NS3 protease was determined,B,,,BAO_0000190,BAO_0000357,single protein format,CC[C@H](NC(=O)[C@H](CC1CCCCC1)NC(=O)[C@@H](NC(=O)[C@H](CC(C)C)NC(=O)c1cnccn1)[C@@H](C)CC)C(=O)C(=O)NC1CC1,,,CHEMBL1136650,Bioorg Med Chem Lett,2003,"{'bei': '8.63', 'le': '0.16', 'lle': '3.31', 'sei': '3.00'}",CHEMBL13514,,CHEMBL13514,5.66,0,http://www.openphacts.org/units/Nanomolar,12758,=,1,1,=,,IC50,nM,,2200.0,CHEMBL4620,Hepatitis C virus genotype 1a (isolate 1) (HCV),Hepatitis C virus polyprotein,11104,,,IC50,uM,UO_0000065,,2.2
# ,,43081,[],CHEMBL857692,Inhibitory concentration against HCV NS3 protease was determined,B,,,BAO_0000190,BAO_0000357,single protein format,CC[C@H](NC(=O)[C@H](CC1CCCCC1)NC(=O)[C@@H](NC(=O)[C@H](CC(C)C)NC(=O)c1cnccn1)[C@@H](C)CC)C(=O)C(=O)N(C)CC(=O)O,,,CHEMBL1136650,Bioorg Med Chem Lett,2003,,CHEMBL274131,,CHEMBL274131,,0,http://www.openphacts.org/units/Nanomolar,12752,>,1,1,>,,IC50,nM,,60000.0,CHEMBL4620,Hepatitis C virus genotype 1a (isolate 1) (HCV),Hepatitis C virus polyprotein,11104,,,IC50,uM,UO_0000065,,60.0
# ,,43082,[],CHEMBL857692,Inhibitory concentration against HCV NS3 protease was determined,B,,,BAO_0000190,BAO_0000357,single protein format,CC[C@H](NC(=O)[C@H](CC1CCCCC1)NC(=O)[C@@H](NC(=O)[C@H](CC(C)C)NC(=O)c1cnccn1)[C@@H](C)CC)C(=O)C(=O)N[C@@H](CC(=O)O)C(=O)O,,,CHEMBL1136650,Bioorg Med Chem Lett,2003,"{'bei': '7.21', 'le': '0.14', 'lle': '4.16', 'sei': '2.01'}",CHEMBL273735,,CHEMBL273735,5.28,0,http://www.openphacts.org/units/Nanomolar,12747,=,1,1,=,,IC50,nM,,5300.0,CHEMBL4620,Hepatitis C virus genotype 1a (isolate 1) (HCV),Hepatitis C virus polyprotein,11104,,,IC50,uM,UO_0000065,,5.3
# ,,45400,[],CHEMBL857692,Inhibitory concentration against HCV NS3 protease was determined,B,,,BAO_0000190,BAO_0000357,single protein format,C#CCNC(=O)C(=O)[C@H](CC)NC(=O)[C@H](CC1CCCCC1)NC(=O)[C@@H](NC(=O)[C@H](CC(C)C)NC(=O)c1cnccn1)[C@@H](C)CC,,,CHEMBL1136650,Bioorg Med Chem Lett,2003,"{'bei': '8.86', 'le': '0.17', 'lle': '3.98', 'sei': '3.08'}",CHEMBL274547,,CHEMBL274547,5.80,0,http://www.openphacts.org/units/Nanomolar,12757,=,1,1,=,,IC50,nM,,1600.0,CHEMBL4620,Hepatitis C virus genotype 1a (isolate 1) (HCV),Hepatitis C virus polyprotein,11104,,,IC50,uM,UO_0000065,,1.6

# %%
df = df[df.standard_value.notna()]
df
# Out:
#     action_type activity_comment  activity_id activity_properties  \
# 0          None             None        33392                  []
# 1          None             None        33393                  []
# 2          None             None        35906                  []
# 3          None             None        40613                  []
# 4          None             None        40614                  []
# ..          ...              ...          ...                 ...
# 238        None           213626     17603004                  []
# 239        None           213627     17603005                  []
# 240        None           214271     17603399                  []
# 241        None           273482     17655802                  []
# 242        None           273483     17655803                  []
#
#     assay_chembl_id                                  assay_description  \
# 0      CHEMBL857692  Inhibitory concentration against HCV NS3 prote...
# 1      CHEMBL857692  Inhibitory concentration against HCV NS3 prote...
# 2      CHEMBL857692  Inhibitory concentration against HCV NS3 prote...
# 3      CHEMBL857692  Inhibitory concentration against HCV NS3 prote...
# 4      CHEMBL857692  Inhibitory concentration against HCV NS3 prote...
# ..              ...                                                ...
# 238   CHEMBL3705251  Inhibition Assay: Briefly, 2-10 nM of purified...
# 239   CHEMBL3705251  Inhibition Assay: Briefly, 2-10 nM of purified...
# 240   CHEMBL3705270  Inhibition Assay: Inhibition activity of HCV N...
# 241   CHEMBL3705926  Polymerase Assay: Assay Protocol: Either wild ...
# 242   CHEMBL3705926  Polymerase Assay: Assay Protocol: Either wild ...
#
#     assay_type assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0            B                    None                   None  BAO_0000190
# 1            B                    None                   None  BAO_0000190
# 2            B                    None                   None  BAO_0000190
# 3            B                    None                   None  BAO_0000190
# 4            B                    None                   None  BAO_0000190
# ..         ...                     ...                    ...          ...
# 238          B                    None                   None  BAO_0000190
# 239          B                    None                   None  BAO_0000190
# 240          B                    None                   None  BAO_0000190
# 241          B                    None                   None  BAO_0000190
# 242          B                    None                   None  BAO_0000190
#
#      ...                                  target_organism  \
# 0    ...  Hepatitis C virus genotype 1a (isolate 1) (HCV)
# 1    ...  Hepatitis C virus genotype 1a (isolate 1) (HCV)
# 2    ...  Hepatitis C virus genotype 1a (isolate 1) (HCV)
# 3    ...  Hepatitis C virus genotype 1a (isolate 1) (HCV)
# 4    ...  Hepatitis C virus genotype 1a (isolate 1) (HCV)
# ..   ...                                              ...
# 238  ...  Hepatitis C virus genotype 1a (isolate 1) (HCV)
# 239  ...  Hepatitis C virus genotype 1a (isolate 1) (HCV)
# 240  ...  Hepatitis C virus genotype 1a (isolate 1) (HCV)
# 241  ...  Hepatitis C virus genotype 1a (isolate 1) (HCV)
# 242  ...  Hepatitis C virus genotype 1a (isolate 1) (HCV)
#
#                   target_pref_name target_tax_id text_value  toid  type units  \
# 0    Hepatitis C virus polyprotein         11104       None  None  IC50    uM
# 1    Hepatitis C virus polyprotein         11104       None  None  IC50    uM
# 2    Hepatitis C virus polyprotein         11104       None  None  IC50    uM
# 3    Hepatitis C virus polyprotein         11104       None  None  IC50    uM
# 4    Hepatitis C virus polyprotein         11104       None  None  IC50    uM
# ..                             ...           ...        ...   ...   ...   ...
# 238  Hepatitis C virus polyprotein         11104       None  None  IC50    nM
# 239  Hepatitis C virus polyprotein         11104       None  None  IC50    nM
# 240  Hepatitis C virus polyprotein         11104       None  None  IC50    nM
# 241  Hepatitis C virus polyprotein         11104       None  None  IC50    nM
# 242  Hepatitis C virus polyprotein         11104       None  None  IC50    nM
#
#        uo_units upper_value    value
# 0    UO_0000065        None     42.0
# 1    UO_0000065        None      4.3
# 2    UO_0000065        None     12.0
# 3    UO_0000065        None      3.6
# 4    UO_0000065        None     60.0
# ..          ...         ...      ...
# 238  UO_0000065        None    950.0
# 239  UO_0000065        None    610.0
# 240  UO_0000065        None    202.0
# 241  UO_0000065        None  27000.0
# 242  UO_0000065        None  18000.0
#
# [242 rows x 46 columns]

# %% [markdown]
# ## Data pre-processing (bioactivity data)

# %% [markdown]
# The bioactivity data is in the I50 unit. Compounds having values of less than 1000 nM will be considered to be active while those greater than 10,000 nM will be considered to be inactive. Values between 1,000 and 10,000 nM will be referred to as interemediate.

# %%
# labeling compounds as either active, inactive, or intermediate
bioactivity_class = []
for i in df.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %%
selection = ['molecule_chembl_id', 'canonical_smiles', 'standard_value']
df = df[selection]

# %%
# pd.concat([df, pd.Series(bioactivity_class)], axis=1)
df2 = pd.DataFrame(data=bioactivity_class, columns=['bioactivity_class'])
df2
# Out:
#     bioactivity_class
# 0            inactive
# 1        intermediate
# 2            inactive
# 3        intermediate
# 4            inactive
# ..                ...
# 237            active
# 238            active
# 239            active
# 240          inactive
# 241          inactive
#
# [242 rows x 1 columns]

# %%
df = df.merge(df2, left_index=True, right_index=True)
df
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL273701  CC[C@H](NC(=O)[C@H](CC1CCCCC1)NC(=O)[C@@H](NC(...
# 1         CHEMBL276488  CC[C@H](NC(=O)[C@H](CC1CCCCC1)NC(=O)[C@@H](NC(...
# 2          CHEMBL13773  CC[C@H](NC(=O)[C@H](CC1CCCCC1)NC(=O)[C@@H](NC(...
# 3          CHEMBL13442  CC[C@H](NC(=O)[C@H](CC1CCCCC1)NC(=O)[C@@H](NC(...
# 4         CHEMBL266854  CC[C@H](C)[C@H](NC(=O)[C@H](CC(C)C)NC(=O)c1cnc...
# ..                 ...                                                ...
# 237      CHEMBL3644938  C=C[C@@H]1C[C@]1(NC(=O)[C@@H]1CN(c2cc(OC)nc(N3...
# 238      CHEMBL3644939  C=C[C@@H]1C[C@]1(NC(=O)[C@@H]1CN(c2cc(Cl)nc(N3...
# 239      CHEMBL3644940  C=C[C@@H]1C[C@]1(NC(=O)[C@@H]1CN(c2cc(Nc3ccccc...
# 240      CHEMBL3659510  CCC[C@H](NC(=O)[C@@H]1[C@@H]2[C@H](CN1C(=O)[C@...
# 241      CHEMBL3686493  C[C@]1(O)[C@@H](O)[C@H](COP(=O)(O)OP(=O)(O)OP(...
#
#     standard_value bioactivity_class
# 0          42000.0          inactive
# 1           4300.0      intermediate
# 2          12000.0          inactive
# 3           3600.0      intermediate
# 4          60000.0          inactive
# ..             ...               ...
# 237         1150.0            active
# 238          950.0            active
# 239          610.0            active
# 240          202.0          inactive
# 241        27000.0          inactive
#
# [241 rows x 4 columns]

# %%
df.to_csv('hepatitis_c_bioactivity_data_preprocessed.csv', index=False)

# %%
! cp hepatitis_c_bioactivity_data_preprocessed.csv "/content/gdrive/My Drive/Colab Notebooks/Computational Drug Discovery: Hepatitis C/hepatitis_c_bioactivity_data_preprocessed.csv"
